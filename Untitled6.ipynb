# %%
import pandas as pd
df=pd.read_csv("sim.csv")
df=df[["Patent's id", 'WWW_link', 'Title',
       'Abstract', 'Publication_date', 'Owner', 'Inventors', 'Image_link','Similarity']]
# Out:
# Index(['Unnamed: 0', 'Patent's id', 'WWW_link', 'Title', 'Abstract',
#        'Publication_date', 'Owner', 'Inventors', 'Image_link', 'Similarity',
#        'patentBERT', 'BERT', 'Roberta'],
#       dtype='object')

# %% [markdown]
# # patentBERT

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load the patentBERT model and tokenizer
def patentBERT(paragraph2):
    model_name = "allenai/scibert_scivocab_uncased"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)


    # Tokenize the paragraphs
    inputs = tokenizer(paragraph1, paragraph2, return_tensors='pt', padding=True, truncation=True, max_length=512)

    # Run the inputs through the model and get the logits
    with torch.no_grad():
        logits = model(**inputs)[0]

    # Calculate the softmax probabilities and get the semantic similarity percentage
    probs = torch.softmax(logits, dim=1)
    similarity_percentage = probs[0][1].item() * 100
    return(round(similarity_percentage,2))
#print(f"The semantic similarity percentage between the two paragraphs is {similarity_percentage:.2f}%")

# %% [markdown]
# # BERT

# %%
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
def BERT(paragraph2):
    # Load pre-trained BERT model and tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')

    # Define the two paragraphs to be compared

    # Tokenize and generate embeddings for both paragraphs
    def generate_embedding(paragraph):
        tokenized_text = tokenizer.tokenize(paragraph)
        indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
        segments_ids = [1] * len(tokenized_text)

        with torch.no_grad():
            tokens_tensor = torch.tensor([indexed_tokens])
            segments_tensors = torch.tensor([segments_ids])
            outputs = model(tokens_tensor, segments_tensors)
            embedding = torch.mean(outputs.last_hidden_state, dim=1).squeeze()

        return embedding

    embedding1 = generate_embedding(paragraph1)
    embedding2 = generate_embedding(paragraph2)

    # Calculate cosine similarity between the two embeddings
    similarity = cosine_similarity(embedding1.reshape(1,-1), embedding2.reshape(1,-1))[0][0]
    return(round(similarity*100,2))
#print("Similarity:", round(similarity*100,2))

# %% [markdown]
# # RoBERTa

# %%
# import torch
from transformers import RobertaTokenizer, RobertaForSequenceClassification
def roberta(paragraph2):
    # Load RoBERTa model and tokenizer
    tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
    model = RobertaForSequenceClassification.from_pretrained('roberta-base')

    # Define the two long paragraphs to compare


    # Tokenize the paragraphs and prepare them as inputs to the model
    inputs = tokenizer(paragraph1, paragraph2, return_tensors='pt', padding=True, truncation=True)

    # Calculate the similarity score using the RoBERTa model
    outputs = model(**inputs)[0]
    similarity_score = torch.softmax(outputs, dim=1)[0][1].item()
    return(round(similarity_score*100,2))
# Print the similarity score as a percentage
#print(f"The similarity score between the two paragraphs is {similarity_score*100:.2f}%.")

# %% [markdown]
# # GPT-3

# %%
import openai
import re
paragraph1 = """When people are using a smartphone (mobile phone) or landline to have a phone conversation then within the phone call their is a button
or an option for any attendee to transfer money using their phone number associated to a digital wallet or a card to the other person and the other
person can request a payment in a certain amount from the other person. The people on the call can confirm the payment over the phone call
through text messages (SMS or MMS) or app notifications. The interface of the phone call app allows users to enter the amount of money to be
transferred using the digits on the keypad using a pop-up or a sequence of numeric commands on the calling app. The transaction happens
seamlessly while maintaining the voice or video call operation as usual."""
def gpt_3(paragraph2,paragraph1):
    # Set up OpenAI API credentials
    openai.api_key = "yours key
    # Define the paragraphs to compare


    # Remove any extra whitespace or line breaks from the paragraphs
    paragraph1 = re.sub('\s+', ' ', paragraph1).strip()
    paragraph2 = re.sub('\s+', ' ', paragraph2).strip()

    # Call the GPT-3 API to calculate the semantic similarity between the two paragraphs
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=f"Calculate the semantic similarity in percentage between the following two paragraphs:\n\n{paragraph1}\n\n{paragraph2}\n\n",
        temperature=0.5,
        max_tokens=1024,
        n=1,
        stop=None,
        timeout=10,
    )

    # Extract the semantic similarity score from the API response
    similarity_score = response.choices[0].text.strip()
    return((re.findall('\d+', similarity_score ))[0])
# Print the semantic similarity score
#rint("Semantic similarity between the two paragraphs:"+ (re.findall('\d+', similarity_score ))[0]+"%")

df['gpt-3']=''
for i in df.index:
    df['gpt-3'][i]=gpt_3(df['Abstract'][i],paragraph1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24476\1169010960.py in <module>
#      37 df['gpt-3']=''
#      38 for i in df.index:
# ---> 39     df['gpt-3'][i]=gpt_3(df['Abstract'][i],paragraph1)
#
# ~\AppData\Local\Temp\ipykernel_24476\1169010960.py in gpt_3(paragraph2, paragraph1)
#      31     # Extract the semantic similarity score from the API response
#      32     similarity_score = response.choices[0].text.strip()
# ---> 33     return((re.findall('\d+', similarity_score ))[0])
#      34 # Print the semantic similarity score
#      35 #rint("Semantic similarity between the two paragraphs:"+ (re.findall('\d+', similarity_score ))[0]+"%")
#
# IndexError: list index out of range

# %%
paragraph1 = """When people are using a smartphone (mobile phone) or landline to have a phone conversation then within the phone call their is a button
or an option for any attendee to transfer money using their phone number associated to a digital wallet or a card to the other person and the other
person can request a payment in a certain amount from the other person. The people on the call can confirm the payment over the phone call
through text messages (SMS or MMS) or app notifications. The interface of the phone call app allows users to enter the amount of money to be
transferred using the digits on the keypad using a pop-up or a sequence of numeric commands on the calling app. The transaction happens
seamlessly while maintaining the voice or video call operation as usual."""
df['patentBERT']=''
df['BERT']=''
df['Roberta']=''
#df['gpt-3']=''
for i in df.index:
    #df['gpt-3'][i]=gpt_3(df['Abstract'][i])
    df['patentBERT'][i]=patentBERT(df['Abstract'][i])
    df['BERT'][i]=BERT(df['Abstract'][i])
    df['Roberta'][i]=roberta(df['Abstract'][i])
# Out:
# Some weights of the model checkpoint at allenai/scibert_scivocab_uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
df.to_csv("sim.csv")
